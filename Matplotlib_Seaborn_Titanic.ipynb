# %% [markdown]
# <a href="https://colab.research.google.com/github/guranshchugh-9/Machine-learning-basics/blob/main/Matplotlib_Seaborn_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🌟 Exploratory Data Analysis with Matplotlib & Seaborn #
# Let's explore data like a data detective! We'll go from simple visualizations to powerful insights using Titanic dataset.
#
# ---

# %% [markdown]
# Before building any machine learning model, EDA helps you understand what’s inside your dataset.
# - Reveals Hidden Patterns
# - Exposes Outliers & Errors
# - Guides Data Cleaning
# - visualise the dataset
# - It helps you understand the structure of data
# - Identify patterns, anomalies, and trends
# - Choose the right ML model & preprocessing steps
#
# It’s like the warm-up before a workout — absolutely essential.

# %% [markdown]
# ## 🧭 1. Introduction to EDA
# **What is EDA?**
# > Exploratory Data Analysis (EDA) is the process of examining a dataset to summarize its main characteristics, often using visual methods.
#
# **Why is it important?**
# - It helps you understand the structure of data
# - Identify patterns, anomalies, and trends
# - Choose the right ML model & preprocessing steps
#
# **Quick Example**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Load Titanic Dataset
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# doubt -  why few have () and few doesnt have this?
# - df.shape
# - df.value_counts()
#
# Think of it like this:
# ✅ Attributes = Info that’s already stored
# - like .shape, .columns, .index
# - like saying: “Tell me the size or labels of the DataFrame”
#
# ⚙️ Methods = Things you ask it to do
# - like .value_counts(), .head(), .describe()
# - like saying: “Hey DataFrame, do something and give me the result”

# %%
df.drop(columns='deck')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# if the block is empty does that mean nan?
# - no not nakko
# - also empty string can be there but its also not included in isna values
# - but its visible in the value_counts

# %% [markdown]
# 🤖 Why do both exist then?
# - isnull() is the original name
#
# - isna() was added later to be more consistent with other methods like fillna(), dropna()
#
# So it’s really just a naming preference.

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Quick visualization: Survival count
sns.countplot(x='sex', data=df)
plt.title("Survival Counts")
# plt.show()
# Out:
# Text(0.5, 1.0, 'Survival Counts')

# %% [markdown]
# # try countplot for sex and class column

# %% [markdown]
# ## 📚 2. Intro to Matplotlib & Seaborn
# - **Matplotlib** is low-level, more control
# - **Seaborn** is high-level, better aesthetics
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# **Tips**:
# - Use `sns.set_theme()` or `sns.set_style('whitegrid')` to make plots pretty
# - Prefer Seaborn for most EDA

# %%
sns.set_theme('paper')

# %%
sns.set_style('whitegrid')  # Try 'darkgrid', 'white', 'ticks', etc.
# sns.set_style('whitegrid')
sns.countplot(x='class', data=df)
plt.title("Passenger Classes")

# %% [markdown]
# ## 📈 3. Univariate Analysis
# **Goal:** Understand a single variable.
#
# ### 🔹 Try This: Plot Age & Fare Distributions

# %% [markdown]
# try countplot for age and fare??
# - If the variable is continuous (like Age, Fare, Height):
# 👉 Use **histplot()** or **kdeplot()**
#
# - If the variable is categorical (like Sex, Class, Embarked):
# 👉 Use **countplot()**

# %% [markdown]
# countplot is also part of univariate analysis

# %%
# Age distribution
sns.histplot(df['age'],kde=True)
plt.title("Age Distribution")
plt.show()

# sns.histplot(df['fare'],kde=Try)

# KDE stands for Kernel Density Estimation. probability density function

# make Fare distribution yourself

# %% [markdown]
# ### 🔹 Mini-task: Countplot of `sex` or `class`

# %%
sns.countplot(x='sex', data=df)
plt.title("Count of Sex")
plt.show()

# %% [markdown]
# ## 📉 4. Bivariate Analysis
# **Goal:** Understand relationships between two variables.
#
# ### 🔹 Try This: Age vs Fare Scatter, Age by Sex Boxplot

# %%
# Scatter plot for two continuos variables
sns.scatterplot(x='age', y='fare', data=df)
plt.title("Age vs Fare")
plt.show()

# scatterplot for sex and age draw
# now draw boxplot
# Boxplot for categories and continuous variables
sns.boxplot(x='sex', y='age', data=df)
plt.title("Age by Sex")
plt.show()

# %% [markdown]
# ## 🧪 5. Multivariate Analysis
# Use hue, style, size to understand 3+ variables!

# %%
# Hue & style in scatterplot
# hue: colour
# differentiate on the basis of class
sns.scatterplot(x='age', y='fare', hue='sex', style='class', data=df)
plt.title("Age vs Fare with Hue & Style")
plt.show()

# Pairplot
sns.pairplot(df[['age', 'fare', 'survived', 'pclass']].dropna(), hue='survived')

# %% [markdown]
# Histograms on the diagonal:
#
# - Check the distribution of variables. For example:
#
# - Age might show a skew towards younger passengers.
#
# - Fare might have a right-skew, showing most passengers paid lower fares.
#
# - Survived will be a binary distribution (0 = No, 1 = Yes).
#
# - Pclass will show a distribution of the three classes.
#
# Scatter plots:
#
# - Look for trends or clusters:
#
# - Age vs. Fare: You might see a wide range of ages for lower fares, and a few older passengers with higher fares.
#
# - Age vs. Survived: You could see if younger or older passengers were more likely to survive.
#
# - Pclass vs. Survived: This might show that higher-class passengers were more likely to survive.

# %% [markdown]
# pairplot, heatmap , 3d scatter plot , violin plot, bubble plot - multivariate

# %% [markdown]
# ## 🧠 6. Correlation & Heatmaps
# Check which features move together!

# %%
# Correlation heatmap
corr = df.corr(numeric_only=True)
# correlation matrix : dependency on each other
# numeric only : leave the values that are not numbers
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
# annot=True	Adds the numeric values (correlation scores) inside each cell.
# cmap='coolwarm'	The color theme: blue for negative, red for positive correlations.
# fmt='.2f'	Format numbers to 2 decimal places, e.g., 0.89 instead of 0.89123.
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# What's a correlation matrix?
# It shows how strongly each numeric column is related to every other numeric column.
#
# The values range from:
#
# +1 → Perfect positive correlation (as one increases, the other increases).
#
# 0 → No correlation.
#
# -1 → Perfect negative correlation (as one increases, the other decreases).
#
# Why numeric_only=True?
# It tells Pandas to only include numeric columns (like age, fare, survived) and skip categorical/text columns (like sex, embarked, etc.).

# %% [markdown]
# ## 🎨 7. Matplotlib Customization
#
# Titles, labels, figure sizes, saving plots

# %%
# Multiple plots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
# figsize: wide*tall
# fig - assume white big sheet
# axs as the individual plots

# subplot- single subplot
# subplots- many subplots

sns.histplot(df['age'], ax=axs[0])
axs[0].set_title('Age Dist')


sns.histplot(df['fare'], ax=axs[1])
axs[1].set_title('Fare Dist')

plt.tight_layout()
plt.savefig("age_fare_dist.png")

# %% [markdown]
# ## 🚀 8. Mini Project: Visual Storytelling with Titanic
# Let's tell a story: Who survived the Titanic?
#
# - Were women more likely to survive?
# - Did class impact survival?

# %%
# Gender vs Survival
sns.barplot(x='sex', y='survived', data=df)
plt.title("Survival Rate by Gender")

# Class vs Survival
sns.barplot(x='pclass', y='survived', data=df)
plt.title("Survival Rate by Class")
# Out:
# Text(0.5, 1.0, 'Survival Rate by Class')

# %% [markdown]
# ## 🎁 9. Bonus Plots
# Let's get fancy!

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y)
plt.title('Line Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# - make list of categories a,b,c
# - values 1,2,3

# %%
categories = ['A', 'B', 'C']
values = [5, 7, 3]

plt.bar(categories, values, color='orange')
plt.title('Bar Plot Example')
plt.show()

# %% [markdown]
# - rand()	Uniform (0 to 1)
# - randn()	Normal (mean 0, std dev 1)

# %% [markdown]
# randn() is super useful in:
#
# Simulating data
#
# Testing statistical models
#
# Plotting histograms
#
# Machine learning (e.g., weight initialization)

# %%
import numpy as np

data = np.random.randn(1000)
plt.hist(data, bins=30, color='purple')
plt.title('Histogram Example')
plt.show()

# %% [markdown]
# - data = [45, 46, 50, 55, 60, 61, 65, 70]
# - bins = 4
# - Python will divide the full range (45 to 70) into 4 equal parts, like:
#
# 45–51
#
# 51–57
#
# 57–63
#
# 63–70
